# %% [markdown]
# \# **Project: Amazon Product Recommendation System**
#
# # **Marked: 60/60**
#
#
# Welcome to the project on Recommendation Systems. We will work with the Amazon product reviews dataset for this project. The dataset contains ratings of different electronic products. It does not include information about the products or reviews to avoid bias while building the model.
#
# --------------
# ## **Context:**
# --------------
#
# Today, information is growing exponentially with volume, velocity and variety throughout the globe. This has lead to information overload, and too many choices for the consumer of any business. It represents a real dilemma for these consumers and they often turn to denial. Recommender Systems are one of the best tools that help recommending products to consumers while they are browsing online. Providing personalized recommendations which is most relevant for the user is what's most likely to keep them engaged and help business.
#
# E-commerce websites like Amazon, Walmart, Target and Etsy use different recommendation models to provide personalized suggestions to different users. These companies spend millions of dollars to come up with algorithmic techniques that can provide personalized recommendations to their users.
#
# Amazon, for example, is well-known for its accurate selection of recommendations in its online site. Amazon's recommendation system is capable of intelligently analyzing and predicting customers' shopping preferences in order to offer them a list of recommended products. Amazon's recommendation algorithm is therefore a key element in using AI to improve the personalization of its website. For example, one of the baseline recommendation models that Amazon uses is item-to-item collaborative filtering, which scales to massive data sets and produces high-quality recommendations in real-time.
#
# ----------------
# ## **Objective:**
# ----------------
#
# You are a Data Science Manager at Amazon, and have been given the task of building a recommendation system to recommend products to customers based on their previous ratings for other products. You have a collection of labeled data of Amazon reviews of products. The goal is to extract meaningful insights from the data and build a recommendation system that helps in recommending products to online consumers.
#
# -----------------------------
# ## **Dataset:**
# -----------------------------
#
# The Amazon dataset contains the following attributes:
#
# - **userId:** Every user identified with a unique id
# - **productId:** Every product identified with a unique id
# - **Rating:** The rating of the corresponding product by the corresponding user
# - **timestamp:** Time of the rating. We **will not use this column** to solve the current problem

# %% [markdown]
# ### **Please read the instructions carefully before starting the project.**
#
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned. Read along carefully to complete the project.
#
# * Blanks '_______' are provided in the notebook that needs to be filled with an appropriate code to get the correct result. Please replace the blank with the right code snippet. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# Fill in the blank" or "# Complete the code". Running incomplete code may throw an error.
# * Remove the blank and state your observations in detail wherever the mark down says 'Write your observations here:_________'
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * You can the results/observations derived from the analysis here and use them to create your final report.

# %% [markdown]
# Sometimes, the installation of the surprise library, which is used to build recommendation systems, faces issues in Jupyter. To avoid any issues, it is advised to use **Google Colab** for this project.
#
# Let's start by mounting the Google drive on Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Installing surprise library**

# %%
# !pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357276 sha256=e0f18560835151d74e13a99a03d02b4a0e0899abbfa76e591f3b60d2baf33a74
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# ...

# %% [markdown]
# ## **Importing the necessary libraries and overview of the dataset**

# %%
import warnings                                 # Used to ignore the warning given as output of the code
warnings.filterwarnings('ignore')

import numpy as np                              # Basic libraries of python for numeric and dataframe computations
import pandas as pd

import matplotlib.pyplot as plt                 # Basic library for data visualization
import seaborn as sns                           # Slightly advanced library for data visualization

from collections import defaultdict             # A dictionary output that does not raise a key error

from sklearn.metrics import mean_squared_error  # A performance metrics in sklearn

# %% [markdown]
# ### **Loading the data**

# %%
# Import the dataset
df = pd.read_csv("/content/drive/MyDrive/Python Course/ratings_Electronics.csv", header = None) # There are no headers in the data file

df.columns = ['user_id', 'prod_id', 'rating', 'timestamp'] # Adding column names

df = df.drop('timestamp', axis = 1) # Dropping timestamp

df_copy = df.copy(deep = True) # Copying the data to another DataFrame

# %% [markdown]
# **As this dataset is very large and has 7,824,482 observations, it is not computationally possible to build a model using this. Moreover, many users have only rated a few products and also some products are rated by very few users. Hence, we can reduce the dataset by considering certain logical assumptions.**
#
# Here, we will be taking users who have given at least 50 ratings, and the products that have at least 5 ratings, as when we shop online we prefer to have some number of ratings of a product.

# %%
# Get the column containing the users
users = df.user_id

# Create a dictionary from users to their number of ratings
ratings_count = dict()

for user in users:

    # If we already have the user, just add 1 to their rating count
    if user in ratings_count:
        ratings_count[user] += 1

    # Otherwise, set their rating count to 1
    else:
        ratings_count[user] = 1

# %%
# We want our users to have at least 50 ratings to be considered
RATINGS_CUTOFF = 50

remove_users = []

for user, num_ratings in ratings_count.items():
    if num_ratings < RATINGS_CUTOFF:
        remove_users.append(user)

df = df.loc[ ~ df.user_id.isin(remove_users)]

# %%
# Get the column containing the products
prods = df.prod_id

# Create a dictionary from products to their number of ratings
ratings_count = dict()

for prod in prods:

    # If we already have the product, just add 1 to its rating count
    if prod in ratings_count:
        ratings_count[prod] += 1

    # Otherwise, set their rating count to 1
    else:
        ratings_count[prod] = 1

# %%
# We want our item to have at least 5 ratings to be considered
RATINGS_CUTOFF = 5

remove_users = []

for user, num_ratings in ratings_count.items():
    if num_ratings < RATINGS_CUTOFF:
        remove_users.append(user)

df_final = df.loc[~ df.prod_id.isin(remove_users)]

# %%
# Print a few rows of the imported dataset
df_final.head()
# Out:
#              user_id     prod_id  rating
# 1310  A3LDPF5FMB782Z  1400501466     5.0
# 1322  A1A5KUIIIHFF4U  1400501466     1.0
# 1335  A2XIOXRRYX0KZY  1400501466     3.0
# 1451   AW3LX47IHPFRL  1400501466     5.0
# 1456  A1E3OB6QMBKRYZ  1400501466     1.0

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### **Shape of the data**

# %%
# Check the number of rows and columns and provide observations
rows, columns = df_final.shape # shape to get the dimensions
print("No of rows: ", rows)
print("No of columns: ", columns)
# Out:
# No of rows:  65290
# No of columns:  3

# %% [markdown]
# **Write your observations here:The dataset, containing 7,824,482 observations, is too large for direct model-building due to computational limitations. Additionally, many users and products have minimal ratings, making the data sparse. To address this, the dataset is reduced by selecting only users who have provided at least 50 ratings and products with at least 5 ratings. This logical filtering results in a streamlined dataset with 65,290 rows focusing on the key columns: user_id, prod_id, and rating.

# %% [markdown]
# ### **Data types**

# %%
# Check Data types and provide observations
df_final.dtypes # dtypes to check the types of the columns
# Out:
# user_id     object
# prod_id     object
# rating     float64
# dtype: object

# %% [markdown]
# **Write your observations here:The “user_id” and “prod_id” are object types, and the “rating” is float64 so that “dtype” is object.
# In Python, the object data type refers to a generic container type that can hold any Python object. It is the most flexible and general data type in Python and is typically used in libraries like pandas or NumPy to indicate mixed or heterogeneous data types within a collection.
# In Python, float64 is a data type representing a 64-bit floating-point number. It is commonly used to store decimal numbers with high precision and is particularly prevalent in numerical computing libraries like NumPy and pandas.
# **

# %% [markdown]
# ### **Checking for missing values**

# %%
# Check for missing values present and provide observations
df_final.isnull().sum() # to count missing values in each column
# Out:
# user_id    0
# prod_id    0
# rating     0
# dtype: int64

# %% [markdown]
# **Write your observations here:There is no missing value because this results in a Series where the index is the column names of df_final and the values are the counts of missing values in each column considering the corresponding value of sum.**

# %% [markdown]
# ### **Summary Statistics**

# %%
# Summary statistics of 'rating' variable and provide observations
df_final['rating'].describe() # 'rating' to access the rating column with describe() to get summary statistics
# Out:
# count    65290.000000
# mean         4.294808
# std          0.988915
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %% [markdown]
# **Write your observations here: We can say the data is heavily skewed towards higher ratings (most values are 4 or 5), reflecting strong user satisfaction with the products.
# There is minimal variability, as seen in the small standard deviation and the clustering of ratings near the maximum score.
# Despite the high average and median, the minimum rating of 1 highlights that some products or experiences still received poor feedback.**

# %% [markdown]
# ### **Checking the rating distribution**

# %%
# Create the bar plot and provide observations
plt.figure(figsize = (12, 6))

df_final['rating'].value_counts(1).plot(kind = 'bar') # with 'bar' to create the bar plot

plt.show()

# %% [markdown]
# **Write your observations here:To sum up, the dataset shows strong overall customer satisfaction, with the majority of ratings being 4.0 or higher. However, the scarcity of lower ratings may require careful consideration when building the recommendation system to ensure fair product differentiation.**

# %% [markdown]
# ### **Checking the number of unique users and items in the dataset**

# %%
# Number of total rows in the data and number of unique user id and product id in the data

print('The number of observations in the final data = ', len(df_final))
print('Number of unique USERS in Raw data = ', df_final['user_id'].nunique())
print('Number of unique ITEMS in Raw data = ', df_final['prod_id'].nunique())
# Out:
# The number of observations in the final data =  65290
# Number of unique USERS in Raw data =  1540
# Number of unique ITEMS in Raw data =  5689

# %% [markdown]
# **Write your observations here:1)	Total Observations: The dataset contains 65,290 rows, representing individual user-product interactions with ratings.
# 2)	Unique Users: There are 1,540 unique users in the dataset. This suggests that a relatively small group of users has rated multiple products.
# 3)	Unique Items: The dataset includes 5,689 unique items (products). This indicates a diverse range of products being rated.
# **

# %% [markdown]
# ### **Users with the most number of ratings**

# %%
# Top 10 users based on the number of ratings # LOL LETS CHECK THE ERROR
most_rated = df_final.groupby('user_id').size().sort_values(ascending = False)[:10]
most_rated
# Out:
# user_id
# ADLVFFE4VBT8      295
# A3OXHLG6DIBRW8    230
# A1ODOGXEYECQQ8    217
# A36K2N527TXXJN    212
# A25C2M3QF9G7OQ    203
# A680RUE1FDO8B     196
# A22CW0ZHY3NJH8    193
# A1UQBFCERIP7VJ    193
# AWPODHOB4GFWL     184
# A3LGT6UZL99IW1    179
# dtype: int64

# %% [markdown]
# - The highest number of **ratings by a user is 295** which is far from the actual number of products present in the data. We can build a recommendation system to recommend products to users which they have not interacted with.

# %% [markdown]
# **Now that we have explored and prepared the data, let's build the first recommendation system.**

# %% [markdown]
# ## **Model 1: Rank Based Recommendation System**

# %%
df_final.head()
# Out:
#              user_id     prod_id  rating
# 1310  A3LDPF5FMB782Z  1400501466     5.0
# 1322  A1A5KUIIIHFF4U  1400501466     1.0
# 1335  A2XIOXRRYX0KZY  1400501466     3.0
# 1451   AW3LX47IHPFRL  1400501466     5.0
# 1456  A1E3OB6QMBKRYZ  1400501466     1.0

# %% [markdown]
# ### Steps:
#
# - **Create the final_rating DataFrame**
# - **Complete the code to create the function top_n_products**
# - **Recommending top 5 products with 50 minimum interactions based on popularity**
# - **Recommending top 5 products with 100 minimum interactions based on popularity**

# %%
# Calculate the average rating for each product
average_rating = df_final.groupby('prod_id')['rating'].mean()

# Calculate the count of ratings for each product
count_rating = df_final.groupby('prod_id')['rating'].count()

# Create a dataframe with calculated average and count of ratings
final_rating = pd.DataFrame({'avg_rating': average_rating, 'rating_count': count_rating})

# Sort the dataframe by average of ratings in the descending order
final_rating = final_rating.sort_values('avg_rating', ascending=False)

# See the first five records of the "final_rating" dataset
final_rating.head()
# Out:
#             avg_rating  rating_count
# prod_id
# B00LGQ6HL8         5.0             5
# B003DZJQQI         5.0            14
# B005FDXF2C         5.0             7
# B00I6CVPVC         5.0             7
# B00B9KOCYA         5.0             8

# %%
# Defining a function to get the top n products based on the highest average rating and minimum interactions

def top_n_products(final_rating, n, min_interaction):

    # Finding products with minimum number of interactions
    recommendations = _____________

    # Sorting values with respect to average rating
    recommendations = _____________

    return recommendations.index[:n]

# %% [markdown]
# ### **Recommending top 5 products with 50 minimum interactions based on popularity**

# %%
def top_n_products(final_rating, n, min_interaction):

    # Finding products with minimum number of interactions
    recommendations = final_rating[final_rating['rating_count'] >= min_interaction]

    # Sorting values with respect to average rating
    recommendations = recommendations.sort_values('avg_rating', ascending=False)

    return recommendations.index[:n]

# %%
# Call the function with desired parameters. For example:
top_products = top_n_products(final_rating, n=5, min_interaction=50)

# Print the top products
print(top_products)
# Out:
# Index(['B001TH7GUU', 'B003ES5ZUU', 'B0019EHU8G', 'B006W8U2MU', 'B000QUUFRW'], dtype='object', name='prod_id')

# %% [markdown]
# ### **Recommending top 5 products with 100 minimum interactions based on popularity**

# %%
# Call the function with desired parameters. For example:
top_products = top_n_products(final_rating, n=5, min_interaction=100)

# Print the top products
print(top_products)
# Out:
# Index(['B003ES5ZUU', 'B000N99BBC', 'B002WE6D44', 'B007WTAJTO', 'B002V88HFE'], dtype='object', name='prod_id')

# %% [markdown]
# We have recommended the **top 5** products by using the popularity recommendation system. Now, let's build a recommendation system using **collaborative filtering.**

# %% [markdown]
# ## **Model 2: Collaborative Filtering Recommendation System**

# %% [markdown]
# In this type of recommendation system, `we do not need any information` about the users or items. We only need user item interaction data to build a collaborative recommendation system. For example -
# <ol>
#     <li><b>Ratings</b> provided by users. For example, ratings of books on goodread, movie ratings on imdb, etc.</li>
#     <li><b>Likes</b> of users on different facebook posts, likes on youtube videos.</li>
#     <li><b>Use/buying</b> of a product by users. For example, buying different items on e-commerce sites.</li>
#     <li><b>Reading</b> of articles by readers on various blogs.</li>
# </ol>

# %% [markdown]
# **Types of Collaborative Filtering**

# %% [markdown]
# - Similarity/Neighborhood based
#
#  * User-User Similarity Based
#  * Item-Item similarity based
#
# - Model based

# %% [markdown]
# ### **Building a baseline user-user similarity based recommendation system**

# %% [markdown]
# - Below, we are building **similarity-based recommendation systems** using `cosine` similarity and using **KNN to find similar users** which are the nearest neighbor to the given user.
# - We will be using a new library, called `surprise`, to build the remaining models. Let's first import the necessary classes and functions from this library.

# %%
# To compute the accuracy of models
from surprise import accuracy

# Class is used to parse a file containing ratings, data should be in structure - user ; item ; rating
from surprise.reader import Reader

# Class for loading datasets
from surprise.dataset import Dataset

# For tuning model hyperparameters
from surprise.model_selection import GridSearchCV

# For splitting the rating data in train and test datasets
from surprise.model_selection import train_test_split

# For implementing similarity-based recommendation system
from surprise.prediction_algorithms.knns import KNNBasic

# For implementing matrix factorization based recommendation system
from surprise.prediction_algorithms.matrix_factorization import SVD

# for implementing K-Fold cross-validation
from surprise.model_selection import KFold

# For implementing clustering-based recommendation system
from surprise import CoClustering

# %% [markdown]
# **Before building the recommendation systems, let's  go over some basic terminologies we are going to use:**

# %% [markdown]
# **Relevant item:** An item (product in this case) that is actually **rated higher than the threshold rating** is relevant, if the **actual rating is below the threshold then it is a non-relevant item**.
#
# **Recommended item:** An item that's **predicted rating is higher than the threshold is a recommended item**, if the **predicted rating is below the threshold then that product will not be recommended to the user**.

# %% [markdown]
# **False Negative (FN):** It is the **frequency of relevant items that are not recommended to the user**. If the relevant items are not recommended to the user, then the user might not buy the product/item. This would result in the **loss of opportunity for the service provider**, which they would like to minimize.
#
# **False Positive (FP):** It is the **frequency of recommended items that are actually not relevant**. In this case, the recommendation system is not doing a good job of finding and recommending the relevant items to the user. This would result in **loss of resources for the service provider**, which they would also like to minimize.

# %% [markdown]
# **Recall:** It is the **fraction of actually relevant items that are recommended to the user**, i.e., if out of 10 relevant products, 6 are recommended to the user then recall is 0.60. Higher the value of recall better is the model. It is one of the metrics to do the performance assessment of classification models.
#
# **Precision:** It is the **fraction of recommended items that are relevant actually**, i.e., if out of 10 recommended items, 6 are found relevant by the user then precision is 0.60. The higher the value of precision better is the model. It is one of the metrics to do the performance assessment of classification models.

# %% [markdown]
# **While making a recommendation system, it becomes customary to look at the performance of the model. In terms of how many recommendations are relevant and vice-versa, below are some most used performance metrics used in the assessment of recommendation systems.**

# %% [markdown]
# ### **Precision@k, Recall@ k, and F1-score@k**

# %% [markdown]
# **Precision@k** - It is the **fraction of recommended items that are relevant in `top k` predictions**. The value of k is the number of recommendations to be provided to the user. One can choose a variable number of recommendations to be given to a unique user.
#
#
# **Recall@k** - It is the **fraction of relevant items that are recommended to the user in `top k` predictions**.
#
# **F1-score@k** - It is the **harmonic mean of Precision@k and Recall@k**. When **precision@k and recall@k both seem to be important** then it is useful to use this metric because it is representative of both of them.

# %% [markdown]
# ### **Some useful functions**

# %% [markdown]
# - Below function takes the **recommendation model** as input and gives the **precision@k, recall@k, and F1-score@k** for that model.
# - To compute **precision and recall**, **top k** predictions are taken under consideration for each user.
# - We will use the precision and recall to compute the F1-score.

# %%
def precision_recall_at_k(model, k = 10, threshold = 3.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user
    user_est_true = defaultdict(list)

    # Making predictions on the test data
    predictions = model.test(testset)

    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key = lambda x: x[0], reverse = True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. Therefore, we are setting Precision to 0 when n_rec_k is 0

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. Therefore, we are setting Recall to 0 when n_rel is 0

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    # Mean of all the predicted precisions are calculated.
    precision = round((sum(prec for prec in precisions.values()) / len(precisions)), 3)

    # Mean of all the predicted recalls are calculated.
    recall = round((sum(rec for rec in recalls.values()) / len(recalls)), 3)

    accuracy.rmse(predictions)

    print('Precision: ', precision) # Command to print the overall precision

    print('Recall: ', recall) # Command to print the overall recall

    print('F_1 score: ', round((2*precision*recall)/(precision+recall), 3)) # Formula to compute the F-1 score

# %% [markdown]
# **Hints:**
#
# - To compute **precision and recall**, a **threshold of 3.5 and k value of 10 can be considered for the recommended and relevant ratings**.
# - Think about the performance metric to choose.

# %% [markdown]
# Below we are loading the **`rating` dataset**, which is a **pandas DataFrame**, into a **different format called `surprise.dataset.DatasetAutoFolds`**, which is required by this library. To do this, we will be **using the classes `Reader` and `Dataset`.**

# %%
df_final.head()
# Out:
#              user_id     prod_id  rating
# 1310  A3LDPF5FMB782Z  1400501466     5.0
# 1322  A1A5KUIIIHFF4U  1400501466     1.0
# 1335  A2XIOXRRYX0KZY  1400501466     3.0
# 1451   AW3LX47IHPFRL  1400501466     5.0
# 1456  A1E3OB6QMBKRYZ  1400501466     1.0

# %%
# Instantiating Reader scale with expected rating scale
reader = Reader(rating_scale = (0, 5))

# Loading the rating dataset
data = Dataset.load_from_df(df_final[['user_id', 'prod_id', 'rating']], reader)

# Splitting the data into train and test datasets
trainset, testset = train_test_split(data, test_size = 0.2, random_state = 42)

# %% [markdown]
# Now, we are **ready to build the first baseline similarity-based recommendation system** using the cosine similarity.

# %% [markdown]
# ### **Building the user-user Similarity-based Recommendation System**
#
# - **Initialize the KNNBasic model using sim_options provided, Verbose=False, and setting random_state=1**
#
# - **Fit the model on the training data**
#
# - **Use the precision_recall_at_k function to calculate the metrics on the test data**
#
# - **Provide your observations on the output**

# %%
# Declaring the similarity options
sim_options = {'name': 'cosine',
               'user_based': True}

# Initialize the KNNBasic model using sim_options provided, Verbose = False, and setting random_state = 1
sim_user_user = KNNBasic(sim_options=sim_options, verbose=False, random_state=1)

# Fit the model on the training data
sim_user_user.fit(trainset)

# Let us compute precision@k, recall@k, and f_1 score using the precision_recall_at_k function defined above
precision_recall_at_k(sim_user_user, k=10, threshold=3.5)
# Out:
# RMSE: 1.0012
# Precision:  0.855
# Recall:  0.858
# F_1 score:  0.856

# %% [markdown]
# **Write your observations here:a.	RMSE (Root Mean Square Error): The RMSE value of 1.0012 indicates how much the predicted ratings deviate, on average, from the true ratings. A lower RMSE value typically means better prediction accuracy.
# b.	Precision: A precision score of 0.855 shows that 85.5% of the top-10 recommended items were relevant, meaning they met or exceeded the threshold of 3.5.
# c.	Recall: The recall score of 0.858 indicates that 85.8% of all relevant items (rated above the threshold) were successfully captured in the top-10 recommendations.
# d.	F1-Score: The F1 score of 0.856 balances precision and recall, indicating strong performance in both recommending relevant items and capturing most of them within the top recommendations.
# **

# %% [markdown]
# Let's now **predict rating for a user with `userId=A3LDPF5FMB782Z` and `productId=1400501466`** as shown below. Here the user has already interacted or watched the product with productId '1400501466' and given a rating of 5 which is denoted by the parameter r_ui.

# %%
# Predicting rating for a sample user with an interacted product
sim_user_user.predict("A3LDPF5FMB782Z", "1400501466", r_ui = 5, verbose = True)
# Out:
# user: A3LDPF5FMB782Z item: 1400501466 r_ui = 5.00   est = 3.40   {'actual_k': 5, 'was_impossible': False}
# Prediction(uid='A3LDPF5FMB782Z', iid='1400501466', r_ui=5, est=3.4, details={'actual_k': 5, 'was_impossible': False})

# %% [markdown]
# **Write your observations here:a.	The actual rating (5.0) significantly differs from the predicted rating (3.40), suggesting that the model may have underpredicted the user's preference for this product.
# b.	The prediction relied on 5 neighbors (actual_k = 5), as per the KNN algorithm used.
# c.	Since was_impossible is False, the model successfully found enough information to make a prediction, indicating sufficient user-item interactions for this scenario
# **

# %% [markdown]
# Below is the function to find the **list of users who have not seen the product with product id "1400501466"**.

# %%
def n_users_not_interacted_with(n, data, prod_id):
    users_interacted_with_product = set(data[data['prod_id'] == prod_id]['user_id'])
    all_users = set(data['user_id'])
    return list(all_users.difference(users_interacted_with_product))[:n] # where n is the number of elements to get in the list

# %%
n_users_not_interacted_with(5, df_final, '1400501466')
# Out:
# ['A35X2JJI49OBZP',
#  'AU3GYRAKBUAEU',
#  'A21VM9WVF8EOSJ',
#  'A1F5O1USOUOOXI',
#  'A2LFWJ8X817QGX']

# %% [markdown]
# * It can be observed from the above list that **user "A2UOHALGF2X77Q" has not seen the product with productId "1400501466"** as this user id is a part of the above list.

# %% [markdown]
# **Below we are predicting rating for `userId=A2UOHALGF2X77Q` and `prod_id=1400501466`.**

# %%
# Predicting rating for a sample user with a non interacted product
sim_user_user.predict("A2UOHALGF2X77Q", "1400501466", verbose = True)
# Out:
# user: A2UOHALGF2X77Q item: 1400501466 r_ui = None   est = 5.00   {'actual_k': 1, 'was_impossible': False}
# Prediction(uid='A2UOHALGF2X77Q', iid='1400501466', r_ui=None, est=5, details={'actual_k': 1, 'was_impossible': False})

# %% [markdown]
# **Write your observations here:*a.	Identification of Non-Interacted Users: The function n_users_not_interacted_with identified users who have not interacted with the product ID 1400501466. From the output, it lists a few such users, including user A2UOHALGF2X77Q.
# b.	Prediction for a Non-Interacted User: The prediction is performed for user A2UOHALGF2X77Q and product 1400501466. Since this user has not interacted with this product, their actual rating (r_ui) is None.
# c.	Estimated Rating: The system estimates a rating of 5.0 for the given product and user. This indicates that the model predicts the user is highly likely to rate the product positively if they were to interact with it.
# d.	Details in Prediction Output: actual_k is 1, which likely refers to the number of nearest neighbors considered for this prediction. was_impossible: False confirms that the prediction process did not encounter any issues.
# *

# %% [markdown]
# ### **Improving Similarity-based Recommendation System by tuning its hyperparameters**

# %% [markdown]
# Below, we will be tuning hyperparameters for the `KNNBasic` algorithm. Let's try to understand some of the hyperparameters of the KNNBasic algorithm:
#
# - **k** (int) – The (max) number of neighbors to take into account for aggregation. Default is 40.
# - **min_k** (int) – The minimum number of neighbors to take into account for aggregation. If there are not enough neighbors, the prediction is set to the global mean of all ratings. Default is 1.
# - **sim_options** (dict) – A dictionary of options for the similarity measure. And there are four similarity measures available in surprise -
#     - cosine
#     - msd (default)
#     - Pearson
#     - Pearson baseline

# %%
# Setting up parameter grid to tune the hyperparameters
param_grid = {
    'k': [20, 30, 40],  # List of values for the max number of neighbors
    'min_k': [3, 6, 9],     # List of values for the min number of neighbors
    'sim_options': {
        'name': ['cosine','msd'],  # Different similarity measures
        'user_based': [True, False]}}

# Performing 3-fold cross-validation to tune the hyperparameters
gs = GridSearchCV(KNNBasic, param_grid, measures = ['rmse'], cv = 3, n_jobs = -1)

# Fitting the data
gs.fit(data)

# Best RMSE score
print(gs.best_score['rmse'])

# Combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 0.9717240113803474
# {'k': 40, 'min_k': 6, 'sim_options': {'name': 'msd', 'user_based': True}}

# %% [markdown]
# Once the grid search is **complete**, we can get the optimal values for each of those hyperparameters** as shown above.

# %% [markdown]
# Now, let's build the **final model by using tuned values of the hyperparameters**, which we received by using **grid search cross-validation**.

# %%
# Using the optimal similarity measure for user-user based collaborative filtering
sim_options = gs.best_params['rmse']['sim_options']

# Creating an instance of KNNBasic with optimal hyperparameter values
sim_user_user_optimized = KNNBasic(sim_options = sim_options, k = gs.best_params['rmse']['k'], min_k = gs.best_params['rmse']['min_k'], random_state = 1, verbose = False)

# Training the algorithm on the train set
sim_user_user_optimized.fit(trainset)

# Let us compute precision@k and recall@k also with k =10
precision_recall_at_k(sim_user_user_optimized, k = 10, threshold = 3.5)
# Out:
# RMSE: 0.9530
# Precision:  0.847
# Recall:  0.893
# F_1 score:  0.869

# %% [markdown]
# **Write your observations here:**a.	Threshold: The threshold=3.5 parameter determines the cutoff for classifying a prediction as relevant (e.g., ratings above 3.5 are considered relevant).
# b.	Precision and Recall Balance: A recall of 0.893 indicates that the model retrieves most of the relevant items. A precision of 0.847 suggests that most of the items retrieved are indeed relevant. The F1 score of 0.869 shows a good balance between precision and recall.
# c.	RMSE is getting lowered from 1.0 in the beginning to 0.97 in the previous and now becomes 0.95. If the current RMSE (0.9530) can be reduced more, the model may make even more accurate predictions.
# ____

# %% [markdown]
# ### **Steps:**
# - **Predict rating for the user with `userId="A3LDPF5FMB782Z"`, and `prod_id= "1400501466"` using the optimized model**
# - **Predict rating for `userId="A2UOHALGF2X77Q"` who has not interacted with `prod_id ="1400501466"`, by using the optimized model**
# - **Compare the output with the output from the baseline model**

# %%
# Use sim_user_user_optimized model to recommend for userId "A3LDPF5FMB782Z" and productId 1400501466

# Assuming you have already fitted the sim_user_user_optimized model:
user_id = "A3LDPF5FMB782Z"
product_id = 1400501466
# Get the predicted rating
predicted_rating = sim_user_user_optimized.predict(user_id, product_id).est

print(f"Predicted rating for user {user_id} and product {product_id}: {predicted_rating}")
# Out:
# Predicted rating for user A3LDPF5FMB782Z and product 1400501466: 4.292024046561495

# %%
# Use sim_user_user_optimized model to recommend for userId "A2UOHALGF2X77Q" and productId "1400501466"
user_id = "A2UOHALGF2X77Q"
product_id = 1400501466

# Get the predicted rating. Notice we're using predict method from sim_user_user_optimized, which was fit earlier
predicted_rating = sim_user_user_optimized.predict(user_id, product_id).est

print(f"Predicted rating for user {user_id} and product {product_id}: {predicted_rating}")
# Out:
# Predicted rating for user A2UOHALGF2X77Q and product 1400501466: 4.292024046561495

# %% [markdown]
# **Write your observations here:**7)	Observations show that for user A3LDPF5FMB782Z and product 1400501466, the predicted rating is 4.2920, and for user A2UOHALGF2X7Q and the same product 1400501466, the predicted rating is also 4.2920.
# We can say the Model shows Consistency. The similarity-based collaborative filtering model (sim_user_user_optimized) has provided identical predicted ratings for both users for the same product. This could suggest that Both users have very similar preferences based on their past interactions. The similarity measure or the neighborhood used in the model results in the same weighted average for this product. It implies that if both users are highly similar in their behavior or the dataset lacks sufficient differentiation for their ratings, the model may assign the same predicted rating.

# %% [markdown]
# ### **Identifying similar Users to a given User (nearest neighbors)**

# %% [markdown]
# We can also find out **similar users to a given user** or its **nearest neighbors** based on this KNNBasic algorithm. Below, we are finding the 5 most similar users to the first user in the list with internal id 0, based on the `msd` distance metric.

# %%
# 0 is the inner id of the user
sim_user_user_optimized.get_neighbors(0, 5)
# Out:
# [6, 42, 44, 54, 66]

# %% [markdown]
# ### **Implementing the recommendation algorithm based on optimized KNNBasic model**

# %% [markdown]
# Below we will be implementing a function where the input parameters are:
#
# - data: A **rating** dataset
# - user_id: A user id **against which we want the recommendations**
# - top_n: The **number of products we want to recommend**
# - algo: the algorithm we want to use **for predicting the ratings**
# - The output of the function is a **set of top_n items** recommended for the given user_id based on the given algorithm

# %%
def get_recommendations(data, user_id, top_n, algo):

    # Creating an empty list to store the recommended product ids
    recommendations = []

    # Creating an user item interactions matrix
    user_item_interactions_matrix = data.pivot(index = 'user_id', columns = 'prod_id', values = 'rating')

    # Extracting those product ids which the user_id has not interacted yet
    non_interacted_products = user_item_interactions_matrix.loc[user_id][user_item_interactions_matrix.loc[user_id].isnull()].index.tolist()

    # Looping through each of the product ids which user_id has not interacted yet
    for item_id in non_interacted_products:

        # Predicting the ratings for those non interacted product ids by this user
        est = algo.predict(user_id, item_id).est

        # Appending the predicted ratings
        recommendations.append((item_id, est))

    # Sorting the predicted ratings in descending order
    recommendations.sort(key = lambda x: x[1], reverse = True)

    return recommendations[:top_n] # Returing top n highest predicted rating products for this user

# %% [markdown]
# **Predicting top 5 products for userId = "A3LDPF5FMB782Z" with similarity based recommendation system**

# %%
# Making top 5 recommendations for user_id "A3LDPF5FMB782Z" with a similarity-based recommendation engine
recommendations = get_recommendations(df_final, "A3LDPF5FMB782Z", 5, sim_user_user_optimized)

# %%
# Building the dataframe for above recommendations with columns "prod_id" and "predicted_ratings"
pd.DataFrame(recommendations, columns = ['prod_id', 'predicted_ratings'])
# Out:
#       prod_id  predicted_ratings
# 0  B000067RT6                  5
# 1  B000BQ7GW8                  5
# 2  B001TH7GUU                  5
# 3  B004RORMF6                  5
# 4  B005ES0YYA                  5

# %% [markdown]
# **Write your observations here:**8)	Implementing the recommendation algorithm based on the optimized KNNBasic model, this model with similar users to a given user (or its nearest neighbors) based on this KNNBasic algorithm shows all predicted ratings for the top 5 products are the maximum value of 5.0. This could indicate that the user's profile and preferences align closely with the ratings of similar users who interacted with these products.

# %% [markdown]
# ### **Item-Item Similarity-based Collaborative Filtering Recommendation System**

# %% [markdown]
# * Above we have seen **similarity-based collaborative filtering** where similarity is calculated **between users**. Now let us look into similarity-based collaborative filtering where similarity is seen **between items**.

# %%
# Declaring the similarity options
sim_options = {'name': 'cosine',
               'user_based': False}

# KNN algorithm is used to find desired similar items
sim_item_item = KNNBasic(sim_options = sim_options, random_state = 1, verbose = False)

# Train the algorithm on the train set, and predict ratings for the test set
sim_item_item.fit(trainset)

# Let us compute precision@k, recall@k, and f_1 score with k = 10
precision_recall_at_k(sim_item_item, k = 10, threshold = 3.5)
# Out:
# RMSE: 0.9950
# Precision:  0.838
# Recall:  0.845
# F_1 score:  0.841

# %% [markdown]
# **Write your observations here:**a.	The model achieves a reasonably low RMSE of 0.9950, indicating that the predictions are relatively close to the actual ratings, though there is still room for improvement.
# b.	With a precision of 0.838, the model accurately identifies relevant items for the user in 83.8% of cases, demonstrating good performance in recommending high-quality items.
# c.	The recall of 0.845 suggests that the model successfully captures 84.5% of all relevant items, highlighting its effectiveness in retrieving items the user might like.
# d.	The balanced F1 score of 0.841 reflects a strong trade-off between precision and recall, making it well-suited for recommendation tasks requiring accuracy and comprehensiveness.
# e.	Overall, while the metrics are strong, the slight gap in RMSE and perfect precision/recall suggests the model might benefit from further tuning or addressing potential biases in predictions.

# %% [markdown]
# Let's now **predict a rating for a user with `userId = A3LDPF5FMB782Z` and `prod_Id = 1400501466`**. Here the user has already interacted or watched the product with productId "1400501466".

# %%
# Predicting rating for a sample user with an interacted product
sim_item_item.predict("A3LDPF5FMB782Z", "1400501466", r_ui = 5, verbose = True) # Pass user ID and product ID as positional arguments
# Out:
# user: A3LDPF5FMB782Z item: 1400501466 r_ui = 5.00   est = 4.27   {'actual_k': 22, 'was_impossible': False}
# Prediction(uid='A3LDPF5FMB782Z', iid='1400501466', r_ui=5, est=4.2727272727272725, details={'actual_k': 22, 'was_impossible': False})

# %% [markdown]
# **Write your observations here:**a.	The model predicted a rating of 4.27 for user A3LDPF5FMB782Z and product 1400501466, which is close to the actual rating of 5.00. This shows that the similarity-based recommendation system is accurate but slightly conservative, likely due to aggregation from 22 similar neighbors. The prediction was successfully generated, indicating the system's robustness and sufficient data density in the dataset.
# b.	However, the model tends to underestimate higher ratings, which could be addressed by fine-tuning parameters like min_k or exploring alternative similarity measures. Overall, the model demonstrates reliable predictive capabilities, making it valuable for real-world applications such as personalized product recommendations.

# %% [markdown]
# Below we are **predicting rating for the `userId = A2UOHALGF2X77Q` and `prod_id = 1400501466`**.

# %%
# Predicting rating for a sample user with a non interacted product
sim_item_item.predict("A2UOHALGF2X77Q", "1400501466", r_ui = 5, verbose = True)
# Out:
# user: A2UOHALGF2X77Q item: 1400501466 r_ui = 5.00   est = 4.00   {'actual_k': 1, 'was_impossible': False}
# Prediction(uid='A2UOHALGF2X77Q', iid='1400501466', r_ui=5, est=4.0, details={'actual_k': 1, 'was_impossible': False})

# %% [markdown]
# **Write your observations here:**a.	In this prediction, the model estimated a rating of 4.00 for user A2UOHALGF2X77Q on the product 1400501466, even though the user had not interacted with this product before. The actual rating provided (r_ui) was 5.00, which shows the model slightly underestimating the user’s preference. The prediction utilized only one neighbor (actual_k: 1), indicating limited data availability for similar users or items in this context. Despite this, the model was able to make a reasonable estimate, demonstrating its capability to generalize even for sparse data.
# b.	However, reliance on a single neighbor might introduce bias or reduce the robustness of predictions, especially for non-interacted items. This result highlights the need to explore enhancements, such as increasing the size of the dataset or adjusting the similarity thresholds, to improve performance for less familiar cases.

# %% [markdown]
# ### **Hyperparameter tuning the item-item similarity-based model**
#
# - Use the following values for the param_grid and tune the model
#   - 'k': [10, 20, 30]
#   - 'min_k': [3, 6, 9]
#   - 'sim_options': {'name': ['msd', 'cosine']
#   - 'user_based': [False]
# - Use GridSearchCV() to tune the model using the 'rmse' measure
# - Print the best score and best parameters

# %%
# Setting up parameter grid to tune the hyperparameters
param_grid = {'k': [10, 20, 30],
    'min_k': [3, 6, 9],
    'sim_options': {
        'name': ['msd', 'cosine'],
        'user_based': [False]
    }}

# Performing 3-fold cross validation to tune the hyperparameters
gs = GridSearchCV(KNNBasic, param_grid, measures=['rmse'], cv=3, n_jobs=-1)

# Fitting the data
gs.fit(data)

# Find the best RMSE score
print(gs.best_score['rmse'])

# Find the combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# 0.974321915977299
# {'k': 30, 'min_k': 6, 'sim_options': {'name': 'msd', 'user_based': False}}

# %% [markdown]
# Once the **grid search** is complete, we can get the **optimal values for each of those hyperparameters as shown above.**

# %% [markdown]
# Now let's build the **final model** by using **tuned values of the hyperparameters** which we received by using grid search cross-validation.

# %%
# Using the optimal similarity measure for item-item based collaborative filtering
sim_options = gs.best_params['rmse']['sim_options']

# Creating an instance of KNNBasic with optimal hyperparameter values
sim_item_item_optimized = KNNBasic(sim_options=sim_options ,  k=gs.best_params['rmse']['k'] , min_k=gs.best_params['rmse']['min_k'],  # Assign the best min_k from GridSearchCV results
                                   random_state = 1, verbose = False)

# Training the algorithm on the train set
sim_item_item_optimized.fit(trainset)

# Let us compute precision@k and recall@k, f1_score and RMSE
precision_recall_at_k(sim_item_item_optimized, k=10, threshold=3.5)
# Out:
# RMSE: 0.9576
# Precision:  0.839
# Recall:  0.88
# F_1 score:  0.859

# %% [markdown]
# **Write your observations here:a.	The model demonstrates strong performance with an RMSE of 0.9576, which is getting lower than 0.995 before tuning in the beginning, indicating a good level of accuracy in predicting user-item ratings.
# b.	A precision of 0.839 signifies that a high proportion of the recommended items are relevant to the users. The recall of 0.88 suggests that the model successfully retrieves a significant number of relevant items, and the F1 score of 0.859 highlights a balanced trade-off between precision and recall, making the model reliable for recommendation tasks
# **

# %% [markdown]
# ### **Steps:**
# - **Predict rating for the user with `userId="A3LDPF5FMB782Z"`, and `prod_id= "1400501466"` using the optimized model**
# - **Predict rating for `userId="A2UOHALGF2X77Q"` who has not interacted with `prod_id ="1400501466"`, by using the optimized model**
# - **Compare the output with the output from the baseline model**

# %%
# Use sim_item_item_optimized model to recommend for userId "A3LDPF5FMB782Z" and productId "1400501466"
user_id = "A3LDPF5FMB782Z"
item_id = "1400501466"
prediction = sim_item_item_optimized.predict(user_id, item_id)
print(f"Predicted rating for user {user_id} and item {item_id}: {prediction.est}")
# Out:
# Predicted rating for user A3LDPF5FMB782Z and item 1400501466: 4.67427701674277

# %%
# Use sim_item_item_optimized model to recommend for userId "A2UOHALGF2X77Q" and productId "1400501466"
user_id = "A2UOHALGF2X77Q"
item_id = "1400501466"
prediction = sim_item_item_optimized.predict(user_id, item_id)
print(f"Predicted rating for user {user_id} and item {item_id}: {prediction.est}")
# Out:
# Predicted rating for user A2UOHALGF2X77Q and item 1400501466: 4.292024046561495

# %% [markdown]
# **Write your observations here:a.	The predicted ratings show that the model estimated a higher rating for user A3LDPF5FMB782Z with the item (4.67) compared to user A2UOHALGF2X77Q (4.29). This indicates that the model considers user A3LDPF5FMB782Z's interaction history more aligned with the item compared to A2UOHALGF2X77Q.
# b.	Both predictions fall within the range of high ratings, suggesting the item is likely relevant to both users, though with varying degrees of confidence.
# **

# %% [markdown]
# ### **Identifying similar items to a given item (nearest neighbors)**

# %% [markdown]
# We can also find out **similar items** to a given item or its nearest neighbors based on this **KNNBasic algorithm**. Below we are finding the 5 most similar items to the item with internal id 0 based on the `msd` distance metric.

# %%
sim_item_item_optimized.get_neighbors(0, k=5)
# Out:
# [29, 53, 67, 106, 151]

# %% [markdown]
# **Predicting top 5 products for userId = "A1A5KUIIIHFF4U" with similarity based recommendation system.**

# %%
# Making top 5 recommendations for user_id A1A5KUIIIHFF4U with similarity-based recommendation engine.
recommendations = get_recommendations(df_final, "A1A5KUIIIHFF4U", 5, sim_item_item_optimized)

# %%
# Building the dataframe for above recommendations with columns "prod_id" and "predicted_ratings"
pd.DataFrame(recommendations, columns = ['prod_id', 'predicted_ratings'])
# Out:
#       prod_id  predicted_ratings
# 0  1400532655           4.292024
# 1  1400599997           4.292024
# 2  9983891212           4.292024
# 3  B00000DM9W           4.292024
# 4  B00000J1V5           4.292024

# %% [markdown]
# **Write your observations here:	Predicting top 5 products for the one userId = "A1A5KUIIIHFF4U" shows the similarity based recommendation system as “4.29”**

# %% [markdown]
# Now as we have seen **similarity-based collaborative filtering algorithms**, let us now get into **model-based collaborative filtering algorithms**.

# %% [markdown]
# ## **Model 3: Matrix Factorization**

# %% [markdown]
# Model-based Collaborative Filtering is a **personalized recommendation system**, the recommendations are based on the past behavior of the user and it is not dependent on any additional information. We use **latent features** to find recommendations for each user.

# %% [markdown]
# ### **Singular Value Decomposition (SVD)**

# %% [markdown]
# SVD is used to **compute the latent features** from the **user-item matrix**. But SVD does not work when we **miss values** in the **user-item matrix**.

# %%
# Using SVD matrix factorization. Use random_state = 1
svd = SVD(random_state=1)

# Training the algorithm on the train set
svd.fit(trainset)

# Use the function precision_recall_at_k to compute precision@k, recall@k, F1-Score, and RMSE
precision_recall_at_k(svd, k=10, threshold=3.5)
# Out:
# RMSE: 0.8882
# Precision:  0.853
# Recall:  0.88
# F_1 score:  0.866

# %% [markdown]
# **Write your observations here:a.	The model shows a solid performance with an RMSE of 0.8882, indicating relatively accurate predictions compared to the true ratings.
# b.	The precision of 0.853 suggests that the recommendations are highly relevant, with most of the recommended items being relevant to the user. A recall of 0.88 indicates that the model is effectively capturing most of the relevant items, and the F1 score of 0.866 reflects a good balance between precision and recall, highlighting the overall effectiveness of the model in making accurate and relevant predictions.
# **

# %% [markdown]
# **Let's now predict the rating for a user with `userId = "A3LDPF5FMB782Z"` and `prod_id = "1400501466`.**

# %%
# Making prediction
svd.predict("A3LDPF5FMB782Z", "1400501466", r_ui = 5, verbose = True)
# Out:
# user: A3LDPF5FMB782Z item: 1400501466 r_ui = 5.00   est = 4.08   {'was_impossible': False}
# Prediction(uid='A3LDPF5FMB782Z', iid='1400501466', r_ui=5, est=4.081406749810685, details={'was_impossible': False})

# %% [markdown]
# **Write your observations here: a.	The first observation shows that the model predicted a rating of 4.08 for user A3LDPF5FMB782Z on item 1400501466, which is lower than the actual rating of 5, suggesting a slight underestimation of the user's preference.**

# %% [markdown]
# **Below we are predicting rating for the `userId = "A2UOHALGF2X77Q"` and `productId = "1400501466"`.**

# %%
# Making prediction
svd.predict("A2UOHALGF2X77Q", "1400501466", verbose = True)
# Out:
# user: A2UOHALGF2X77Q item: 1400501466 r_ui = None   est = 4.16   {'was_impossible': False}
# Prediction(uid='A2UOHALGF2X77Q', iid='1400501466', r_ui=None, est=4.156510633154892, details={'was_impossible': False})

# %% [markdown]
# **Write your observations here:
# b.	In the second case, for user A2UOHALGF2X77Q, who hasn't rated the item yet(r_ui = None), the model predicted a rating of 4.16, which is a reasonable estimate based on similar users or items. These observations demonstrate that the model can make reasonable predictions, but the accuracy can vary, especially when users have no prior interaction with the item.
# **

# %% [markdown]
# ### **Improving Matrix Factorization based recommendation system by tuning its hyperparameters**

# %% [markdown]
# Below we will be tuning only three hyperparameters:
# - **n_epochs**: The number of iterations of the SGD algorithm.
# - **lr_all**: The learning rate for all parameters.
# - **reg_all**: The regularization term for all parameters.

# %%
# Set the parameter space to tune
param_grid = {'n_epochs': [10, 20, 30], 'lr_all': [0.001, 0.005, 0.01],
              'reg_all': [0.2, 0.4, 0.6]}

# Performing 3-fold gridsearch cross-validation
gs_ = GridSearchCV(SVD, param_grid, measures = ['rmse'], cv = 3, n_jobs = -1)

# Fitting data
gs_.fit(data)

# Best RMSE score
print(gs_.best_score['rmse'])

# Combination of parameters that gave the best RMSE score
print(gs_.best_params)
# Out:
# 0.8975957881211349
# {'rmse': {'n_epochs': 20, 'lr_all': 0.01, 'reg_all': 0.2}}

# %% [markdown]
# Now, we will **the build final model** by using **tuned values** of the hyperparameters, which we received using grid search cross-validation above.

# %%
# Build the optimized SVD model using optimal hyperparameter search. Use random_state = 1
svd_optimized = SVD(n_epochs=gs_.best_params['rmse']['n_epochs'],
                    lr_all=gs_.best_params['rmse']['lr_all'],
                    reg_all=gs_.best_params['rmse']['reg_all'],
                    random_state=1)

# Train the algorithm on the train set
svd_optimized.fit(trainset)

# Use the function precision_recall_at_k to compute precision@k, recall@k, F1-Score, and RMSE
precision_recall_at_k(svd_optimized, k=10, threshold=3.5)
# Out:
# RMSE: 0.8808
# Precision:  0.854
# Recall:  0.878
# F_1 score:  0.866

# %% [markdown]
# **Write your observations here:The optimized SVD model achieves an RMSE of 0.8808, which is lower than the previous RMSE of 0.8882, indicating improved accuracy in predicting user ratings. The Precision has slightly increased to 0.854, reflecting a higher proportion of relevant recommendations among those suggested. Similarly, the Recall improved to 0.878, demonstrating better coverage of relevant items in the recommendations. The F1-Score remains stable at 0.866, showing a balanced enhancement of precision and recall. These improvements suggest that tuning hyperparameters like n_epochs, lr_all, and reg_all has led to a more effective recommendation model that captures latent features more precisely.**

# %% [markdown]
# **Let's now predict a rating for a user with `userId = "A3LDPF5FMB782Z"` and `productId = "1400501466"` with the optimized model.**

# %% [markdown]
# ### **Steps:**
# - **Predict rating for the user with `userId="A3LDPF5FMB782Z"`, and `prod_id= "1400501466"` using the optimized model**
# - **Predict rating for `userId="A2UOHALGF2X77Q"` who has not interacted with `prod_id ="1400501466"`, by using the optimized model**
# - **Compare the output with the output from the baseline model**

# %%
# Use svd_algo_optimized model to recommend for userId "A3LDPF5FMB782Z" and productId "1400501466"
prediction = svd_optimized.predict("A3LDPF5FMB782Z", "1400501466", r_ui = 5, verbose = True).est

print(f"Predicted rating for user 'A3LDPF5FMB782Z' and product '1400501466': {prediction}")
# Out:
# user: A3LDPF5FMB782Z item: 1400501466 r_ui = 5.00   est = 4.13   {'was_impossible': False}
# Predicted rating for user 'A3LDPF5FMB782Z' and product '1400501466': 4.128589011282042

# %%
# Use svd_algo_optimized model to recommend for userId "A2UOHALGF2X77Q" and productId "1400501466"
prediction = svd_optimized.predict("A2UOHALGF2X77Q", "1400501466", verbose = True).est

print(f"Predicted rating for user 'A2UOHALGF2X77Q' and product '1400501466': {prediction}")
# Out:
# user: A2UOHALGF2X77Q item: 1400501466 r_ui = None   est = 4.11   {'was_impossible': False}
# Predicted rating for user 'A2UOHALGF2X77Q' and product '1400501466': 4.105349444662267

# %% [markdown]
# **Write your observations here:**a.	The optimized SVD model predicts a rating of 4.13 for user A3LDPF5FMB782Z for product 1400501466, close to the actual value of 5.00, showing accuracy for known interactions.
# b.	For user A2UOHALGF2X77Q, it predicts 4.11 for an unseen product, demonstrating its ability to generalize well.

# %% [markdown]
# ### **Conclusion and Recommendations**

# %% [markdown]
# **Write your conclusion and recommendations here**

# %% [markdown]
# Model Comparison and Final Model Selection:
# 1. Rank-Based Model
# Performance: Simple, non-personalized recommendations based on overall popularity or ratings.
# Strengths: Easy to implement and effective for new users/items (cold start problem).
# Weaknesses: Ignores individual preferences, leading to a lack of personalization.
# Use Case: Works well in scenarios where personalization is less critical.
# 2. User-User Similarity-Based Model
# Performance: Recommendations are based on similar users' preferences.
# Strengths: Personalizes recommendations by leveraging user interactions.
# Weaknesses: Struggles with scalability as the number of users grows. Performs poorly with sparse data.
# Use Case: Effective for dense datasets with many overlapping user interactions.
# 3. Item-Item Similarity-Based Model
# Performance: Recommendations are based on items similar to those the user has interacted with.
# Strengths: Scales better than user-user models and performs well with sparse datasets.
# Weaknesses: Limited ability to capture evolving user preferences.
# Use Case: Ideal for large datasets and when item similarity remains stable over time.
# 4. Matrix Factorization-Based Model (SVD)
# Performance: Uses latent factors derived from the user-item interaction matrix to make recommendations.
# Strengths: Highly accurate and captures complex relationships between users and items. Handles sparsity well.
# Weaknesses: Requires tuning and more computational resources for training.
# Use Case: Best for datasets with enough historical interactions and when personalization is crucial.
#
# 5. Insights with several examples: Choosing an appropriate similarity improved how well similar users or items were identified. Adjusting the number of neighbors refined predictions by balancing relevance and diversity. Modifying thresholds impacted the classification of items as relevant or irrelevant, which directly affected precision and recall. Post-tuning, the model became more adept at tailoring recommendations, balancing prediction accuracy, and producing actionable insights.
#
# 6. Final Model Selection - The Matrix Factorization-Based Model (SVD with hyperparameter tuning) is the most suitable choice due to its superior precision (0.854), recall (0.878), F1 score (0.866), and RMSE (0.8808). It effectively captures latent relationships between users and items, providing highly personalized recommendations. While other models have specific strengths, SVD strikes the best balance between accuracy and scalability, making it ideal for production in recommendation systems.
#
# 7. To improve business outcomes using recommendation systems, consider the following actionable recommendations:
#
# (1) Implement a Hybrid Approach: Combine models, such as Rank-Based and Matrix Factorization, to leverage the simplicity of popularity-based recommendations and the personalization of latent factor modeling. This approach balances accuracy and scalability.
#
# (2) Enhance Data Collection: Improve the quantity and quality of user-item interaction data. Encourage users to provide explicit feedback (e.g., ratings or reviews) and track implicit interactions (e.g., clicks, dwell time).
#
# (3) Address the Cold Start Problem: Use the Rank-Based model or content-based filtering for new users and items, while gradually transitioning to personalized recommendations as interactions grow.
#
# (4) Optimize Scalability: For growing datasets, prioritize Item-Item Similarity models or Matrix Factorization with efficient implementations like SVD++, which can handle sparsity and large-scale computations effectively.
#
# (5) Continuous Monitoring and Tuning: Regularly monitor model performance metrics (e.g., RMSE, precision, recall) and use A/B testing to identify areas for improvement. Fine-tune hyperparameters to maintain or improve recommendation quality.
#
# (6) Personalize Marketing Strategies: Use user-specific insights from personalized recommendations to drive targeted marketing campaigns, such as tailored promotions or email recommendations.
#
# (7) By leveraging these recommendations, businesses can improve user engagement, increase conversion rates, and ultimately drive revenue growth.
